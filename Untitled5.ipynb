# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
from collections import defaultdict
import sys
import string
import os
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact
import nbinteract as nbi
import time

punctuation = set(string.punctuation)
dir = "booksdir"

def parsefile(filename):
    try:
        file = open(filename, "r")
    except FileNotFoundError:
        print(filename, "is missing from your current directory")
        sys.exit(-1) # quits the program
    lines = file.readlines()
    file.close()
    return lines

def createMap(lines):
    words = defaultdict(int)
    for l in lines:
        l = l.strip()
        l = ''.join(ch for ch in l if ch not in punctuation)
        l = l.lower().split(" ")
        for w in l:
            words[w] += 1
    return words

if __name__ == "__main__":

    directory = os.fsencode(dir)

    books = {}
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.endswith(".txt"):
             try:
                 file_name = dir+'/'+filename
             except FileNotFoundError:
                 print("Cannot find file")
                 sys.exit(-1)

             lines = parsefile(file_name)
             words = createMap(lines)
             books[filename] = words

    objects = list(books.keys())

    y_pos = np.arange(len(objects))

    def update(word):
        inputword = word
        time.sleep(5)
        performance = []
        for title in objects:
            performance.append(books[title][inputword])
        fig = go.Figure([go.Bar(x=objects, y=performance, name=inputword)])
        fig.show()
        return

    interact_manuel(update, word='word');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b9348fd67499> in <module>
#      65         return
#      66
# ---> 67     interact_manuel(update, word='word');
#
# NameError: name 'interact_manuel' is not defined

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
from collections import defaultdict
import sys
import string
import os
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact
import nbinteract as nbi
import time

punctuation = set(string.punctuation)
dir = "booksdir"

def parsefile(filename):
    try:
        file = open(filename, "r")
    except FileNotFoundError:
        print(filename, "is missing from your current directory")
        sys.exit(-1) # quits the program
    lines = file.readlines()
    file.close()
    return lines

def createMap(lines):
    words = defaultdict(int)
    for l in lines:
        l = l.strip()
        l = ''.join(ch for ch in l if ch not in punctuation)
        l = l.lower().split(" ")
        for w in l:
            words[w] += 1
    return words

if __name__ == "__main__":

    directory = os.fsencode(dir)

    books = {}
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.endswith(".txt"):
             try:
                 file_name = dir+'/'+filename
             except FileNotFoundError:
                 print("Cannot find file")
                 sys.exit(-1)

             lines = parsefile(file_name)
             words = createMap(lines)
             books[filename] = words

    objects = list(books.keys())

    y_pos = np.arange(len(objects))

    def update(word):
        inputword = word
        time.sleep(5)
        performance = []
        for title in objects:
            performance.append(books[title][inputword])
        fig = go.Figure([go.Bar(x=objects, y=performance, name=inputword)])
        fig.show()
        return

    interact_manual(update, word='word');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-210c14bc3176> in <module>
#      65         return
#      66
# ---> 67     interact_manual(update, word='word');
#      68
#
# NameError: name 'interact_manual' is not defined

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
from collections import defaultdict
import sys
import string
import os
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact_manual
import nbinteract as nbi
import time

punctuation = set(string.punctuation)
dir = "booksdir"

def parsefile(filename):
    try:
        file = open(filename, "r")
    except FileNotFoundError:
        print(filename, "is missing from your current directory")
        sys.exit(-1) # quits the program
    lines = file.readlines()
    file.close()
    return lines

def createMap(lines):
    words = defaultdict(int)
    for l in lines:
        l = l.strip()
        l = ''.join(ch for ch in l if ch not in punctuation)
        l = l.lower().split(" ")
        for w in l:
            words[w] += 1
    return words

if __name__ == "__main__":

    directory = os.fsencode(dir)

    books = {}
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.endswith(".txt"):
             try:
                 file_name = dir+'/'+filename
             except FileNotFoundError:
                 print("Cannot find file")
                 sys.exit(-1)

             lines = parsefile(file_name)
             words = createMap(lines)
             books[filename] = words

    objects = list(books.keys())

    y_pos = np.arange(len(objects))

    def update(word):
        inputword = word
        time.sleep(5)
        performance = []
        for title in objects:
            performance.append(books[title][inputword])
        fig = go.Figure([go.Bar(x=objects, y=performance, name=inputword)])
        fig.show()
        return

    interact_manual(update, word='word');
# Out:
# interactive(children=(Text(value='word', description='word'), Button(description='Run Interact', style=ButtonS…

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
from collections import defaultdict
import sys
import string
import os
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact_manual
import nbinteract as nbi
import time

punctuation = set(string.punctuation)
dir = "booksdir"

def parsefile(filename):
    try:
        file = open(filename, "r")
    except FileNotFoundError:
        print(filename, "is missing from your current directory")
        sys.exit(-1) # quits the program
    lines = file.readlines()
    file.close()
    return lines

def createMap(lines):
    words = defaultdict(int)
    for l in lines:
        l = l.strip()
        l = ''.join(ch for ch in l if ch not in punctuation)
        l = l.lower().split(" ")
        for w in l:
            words[w] += 1
    return words

if __name__ == "__main__":

    directory = os.fsencode(dir)

    books = {}
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.endswith(".txt"):
             try:
                 file_name = dir+'/'+filename
             except FileNotFoundError:
                 print("Cannot find file")
                 sys.exit(-1)

             lines = parsefile(file_name)
             words = createMap(lines)
             books[filename] = words

    objects = list(books.keys())

    y_pos = np.arange(len(objects))

    def update(word):
        inputword = word
        performance = []
        for title in objects:
            performance.append(books[title][inputword])
        fig = go.Figure([go.Bar(x=objects, y=performance, name=inputword)])
        fig.show()
        return

    interact_manual(update, word='word');
# Out:
# interactive(children=(Text(value='word', description='word'), Button(description='Run Interact', style=ButtonS…

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
from collections import defaultdict
import sys
import string
import os
import numpy as np
import plotly.graph_objects as go
from ipywidgets import interact_manual
import nbinteract as nbi
import time

punctuation = set(string.punctuation)
dir = "booksdir"

def parsefile(filename):
    try:
        file = open(filename, "r")
    except FileNotFoundError:
        print(filename, "is missing from your current directory")
        sys.exit(-1) # quits the program
    lines = file.readlines()
    file.close()
    return lines

def createMap(lines):
    words = defaultdict(int)
    for l in lines:
        l = l.strip()
        l = ''.join(ch for ch in l if ch not in punctuation)
        l = l.lower().split(" ")
        for w in l:
            words[w] += 1
    return words

if __name__ == "__main__":

    directory = os.fsencode(dir)

    books = {}
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.endswith(".txt"):
             try:
                 file_name = dir+'/'+filename
             except FileNotFoundError:
                 print("Cannot find file")
                 sys.exit(-1)

             lines = parsefile(file_name)
             words = createMap(lines)
             books[filename] = words

    objects = list(books.keys())

    y_pos = np.arange(len(objects))

    def update(word):
        inputword = word
        performance = []
        for title in objects:
            performance.append(books[title][inputword])
        fig = go.Figure([go.Bar(x=objects, y=performance, name=inputword)])
        fig.show()
        return

    interact_manual(update, word='type word here');
# Out:
# interactive(children=(Text(value='type word here', description='word'), Button(description='Run Interact', sty…

# %%
import dash
import dash_html_components as html
import dash_core_components as dcc

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app = dash.Dash(__name__, external_stylesheets=external_stylesheets)
app.layout = html.Div([
    html.Div(dcc.Input(id='input-box', type='text')),
    html.Button('Submit', id='button'),
    html.Div(id='output-container-button',
             children='Enter a value and press submit')
])


@app.callback(
    dash.dependencies.Output('output-container-button', 'children'),
    [dash.dependencies.Input('button', 'n_clicks')],
    [dash.dependencies.State('input-box', 'value')])
def update_output(n_clicks, value):
    return 'The input value was "{}" and the button has been clicked {} times'.format(
        value,
        n_clicks
    )


if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
# Running on http://127.0.0.1:8050/
# Debugger PIN: 892-106-667
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-79028c7b27da> in <module>
#      26
#      27 if __name__ == '__main__':
# ---> 28     app.run_server(debug=True)
#      29
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/dash/dash.py in run_server(self, port, debug, dev_tools_ui, dev_tools_props_check, dev_tools_serve_dev_bundles, dev_tools_hot_reload, dev_tools_hot_reload_interval, dev_tools_hot_reload_watch_interval, dev_tools_hot_reload_max_retry, dev_tools_silence_routes_logging, dev_tools_prune_errors, **flask_run_options)
#    2022             self.logger.info("Debugger PIN: %s", debugger_pin)
#    2023
# -> 2024         self.server.run(port=port, debug=debug, **flask_run_options)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/flask/app.py in run(self, host, port, debug, load_dotenv, **options)
#     988
#     989         try:
# --> 990             run_simple(host, port, self, **options)
#     991         finally:
#     992             # reset the first request information if the development server
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/werkzeug/serving.py in run_simple(hostname, port, application, use_reloader, use_debugger, use_evalex, extra_files, reloader_interval, reloader_type, threaded, processes, request_handler, static_files, passthrough_errors, ssl_context)
#     986             s = socket.socket(address_family, socket.SOCK_STREAM)
#     987             s.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# --> 988             s.bind(server_address)
#     989             if hasattr(s, "set_inheritable"):
#     990                 s.set_inheritable(True)
#
# OSError: [Errno 48] Address already in use
